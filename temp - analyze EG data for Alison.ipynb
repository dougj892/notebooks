# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_stata(r"C:\Users\dougj\Dropbox (IDinsight)\Documents from mac laptop\code\Educate Girls DIB Analysis\End line datasets\Type I-III Students ELY3.dta")

# %%
df
# Out:
#                  type               schoolname school_code  treatment  \
# 0     Baseline Sample      G.P.S SANST GANDHER  8241000108          1
# 1     Baseline Sample      G.P.S SANST GANDHER  8241000108          1
# 2     Baseline Sample      G.P.S SANST GANDHER  8241000108          1
# 3     Baseline Sample      G.P.S SANST GANDHER  8241000108          1
# 4     Baseline Sample      G.P.S SANST GANDHER  8241000108          1
# 5     Baseline Sample      G.P.S SANST GANDHER  8241000108          1
# 6     Baseline Sample      G.P.S SANST GANDHER  8241000108          1
# 7     Baseline Sample      G.P.S SANST GANDHER  8241000108          1
# 8     Baseline Sample      G.P.S SANST GANDHER  8241000108          1
# 9     Baseline Sample      G.P.S SANST GANDHER  8241000108          1
# 10    Baseline Sample      G.P.S SANST GANDHER  8241000108          1
# 11    Baseline Sample      G.P.S SANST GANDHER  8241000108          1
# ...

# %%
df.dtypes
# Out:
# type                                   category
# schoolname                               object
# school_code                              object
# treatment                                  int8
# pair_id                                 float64
# child_id                                 object
# child_name                               object
# child_father                             object
# child_mother                             object
# child_caste                              object
# child_caste_cat                        category
# child_gender                             object
# child_class_ely3                       category
# child_class_bl                         category
# child_class_ely1                       category
# child_class_ely2                       category
# child_roll_ely3                         float64
# child_roll_bl                           float64
# child_roll_ely1                         float64
# child_roll_ely2                         float64
# ...
