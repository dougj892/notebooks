# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import os
os.chdir(r"C:\Users\dougj\Documents\Satellite sampling ground truth sample")

# %%
segs = gpd.read_file(r"Final sample\Final selected segments\final_segments.shp")

# %%
segs
# Out:
#     unique_id  num_segmen  population      state   new_pop  num_subbox  \
# 0        3627           1        2396      bihar   599.000           4
# 1       13717           1        7200      bihar  1800.000           4
# 2       28753           1         336      bihar   336.000           1
# 3       29874           1       10607      bihar  1178.556           9
# 4       34552           1         811      bihar   811.000           1
# 5       36749           1       19764      bihar  1235.250          16
# 6       45057           1        1728      bihar  1728.000           1
# 7       61412           1        5052      bihar  1263.000           4
# 8       66294           1         483      bihar   483.000           1
# 9      125031           1        8063         UP  2015.750           4
# 10     222630           1       32934         UP  1317.360          25
# 11     223048           1        6511         UP  1627.750           4
# ...
